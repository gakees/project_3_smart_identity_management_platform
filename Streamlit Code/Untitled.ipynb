# %%
pip install streamlit-authenticator
# Out:
# ...
#      |████████████████████████████████| 2.3 MB 3.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 49 kB 12.0 MB/s eta 0:00:01
# ...
#   Created wheel for streamlit-authenticator: filename=streamlit_authenticator-0.1.0-py3-none-any.whl size=4794 sha256=575a155efe7011ee0be1a9962b7b504f985e11148806b3e412ae5e50b87b16bc
#   Stored in directory: /Users/Brittany/Library/Caches/pip/wheels/e1/f5/52/4f67a5c32ed7a6e968e4223b07bfa3ccee565832f82ac8a4b3
# Successfully built streamlit-authenticator
# ...
# Note: you may need to restart the kernel to use updated packages.
